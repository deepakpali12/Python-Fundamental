# %%
a="34"
[print(a)]
b=bool(a)
type(b)
# Out:
# 34
# bool

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\hp\\Documents\\NITISH_SIR_JI\\Mall_Customers.csv")

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 245         246    Male   30                 297                      69
# 246         247  Female   56                 311                      14
# 247         248    Male   29                 313                      90
# 248         249  Female   19                 316                      32
# 249         250  Female   31                 325                      86
#
# [250 rows x 5 columns]

# %%
df.head(4)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77

# %%
df.info
# Out:
# <bound method DataFrame.info of      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 245         246    Male   30                 297                      69
# 246         247  Female   56                 311                      14
# 247         248    Male   29                 313                      90
# 248         249  Female   19                 316                      32
# 249         250  Female   31                 325                      86
#
# [250 rows x 5 columns]>

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df['Gender']=df['Gender'].str.lower()

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    male   19                  15                      39
# 1             2    male   21                  15                      81
# 2             3  female   20                  16                       6
# 3             4  female   23                  16                      77
# 4             5  female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 245         246    male   30                 297                      69
# 246         247  female   56                 311                      14
# 247         248    male   29                 313                      90
# 248         249  female   19                 316                      32
# 249         250  female   31                 325                      86
#
# [250 rows x 5 columns]

# %%
df['Gender']=df['Gender'].str.upper()

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    MALE   19                  15                      39
# 1             2    MALE   21                  15                      81
# 2             3  FEMALE   20                  16                       6
# 3             4  FEMALE   23                  16                      77
# 4             5  FEMALE   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 245         246    MALE   30                 297                      69
# 246         247  FEMALE   56                 311                      14
# 247         248    MALE   29                 313                      90
# 248         249  FEMALE   19                 316                      32
# 249         250  FEMALE   31                 325                      86
#
# [250 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              250 non-null    int64
#  1   Gender                  250 non-null    object
#  2   Age                     250 non-null    int64
#  3   Annual Income (k$)      250 non-null    int64
#  4   Spending Score (1-100)  250 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 9.9+ KB

# %%
df['CustomerID'].value_counts()
# Out:
# CustomerID
# 1      1
# 172    1
# 159    1
# 160    1
# 161    1
#       ..
# 89     1
# 90     1
# 91     1
# 92     1
# 250    1
# Name: count, Length: 250, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
 df['Age'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
df1=pd.read_csv("C://Users//hp//Documents//NITISH_SIR_JI//SampleSuperstore (1).csv")

# %%
df1
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df1.head(5)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df1.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df1.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df1['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df1['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df1['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
df1['Sub-Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
(df1['Sub-Category'].value_counts()).sort_values()
# Out:
# Sub-Category
# Copiers          68
# Machines        115
# Supplies        190
# Fasteners       217
# Bookcases       228
# Envelopes       254
# Tables          319
# Labels          364
# Appliances      466
# Chairs          617
# Accessories     775
# Art             796
# Storage         846
# Phones          889
# Furnishings     957
# Paper          1370
# Binders        1523
# Name: count, dtype: int64

# %%
df4=pd.read_csv("C:\\Users\\hp\\Desktop\\IRIS.csv")

# %%
df4
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df4.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df4.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df4.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df5=pd.read_csv(r"C:\Users\hp\Desktop\HIGH COURT1.csv")

# %%
df5
# Out:
#     Country           State                             Year  \
# 0     India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 1     India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 2     India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 3     India           Assam  Calendar Year (Jan - Dec), 2024
# 4     India           Assam  Calendar Year (Jan - Dec), 2024
# ..      ...             ...                              ...
# 133   India     West Bengal  Calendar Year (Jan - Dec), 2024
# 134   India     West Bengal  Calendar Year (Jan - Dec), 2024
# 135   India     West Bengal  Calendar Year (Jan - Dec), 2024
# 136   India     West Bengal  Calendar Year (Jan - Dec), 2024
# 137   India     West Bengal  Calendar Year (Jan - Dec), 2024
#
#                   High Court Name                High Court Bench  \
# 0    High Court of Andhra Pradesh  Principal Bench Andhra Pradesh
# 1    High Court of Andhra Pradesh  Principal Bench Andhra Pradesh
# ...

# %%
import pandas as pd

# %%
df5.head(5)
# Out:
#   Country           State                             Year  \
# 0   India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 1   India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 2   India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 3   India           Assam  Calendar Year (Jan - Dec), 2024
# 4   India           Assam  Calendar Year (Jan - Dec), 2024
#
#                 High Court Name                High Court Bench  \
# 0  High Court of Andhra Pradesh  Principal Bench Andhra Pradesh
# 1  High Court of Andhra Pradesh  Principal Bench Andhra Pradesh
# 2  High Court of Andhra Pradesh  Principal Bench Andhra Pradesh
# 3            Gauhati High Court                    Aizawl Bench
# 4            Gauhati High Court                    Aizawl Bench
#
#   Court Case Type As On Date  \
# 0           Civil  10-Jul-24
# 1        Criminal  10-Jul-24
# 2           Total  10-Jul-24
# 3           Civil  10-Jul-24
# 4        Criminal  10-Jul-24
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df5.head()
# Out:
#   Country           State                             Year  \
# 0   India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 1   India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 2   India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 3   India           Assam  Calendar Year (Jan - Dec), 2024
# 4   India           Assam  Calendar Year (Jan - Dec), 2024
#
#                 High Court Name                High Court Bench  \
# 0  High Court of Andhra Pradesh  Principal Bench Andhra Pradesh
# 1  High Court of Andhra Pradesh  Principal Bench Andhra Pradesh
# 2  High Court of Andhra Pradesh  Principal Bench Andhra Pradesh
# 3            Gauhati High Court                    Aizawl Bench
# 4            Gauhati High Court                    Aizawl Bench
#
#   Court Case Type As On Date  \
# 0           Civil  10-Jul-24
# 1        Criminal  10-Jul-24
# 2           Total  10-Jul-24
# 3           Civil  10-Jul-24
# 4        Criminal  10-Jul-24
#
# ...

# %%
df5.head()
# Out:
#   Country           State                             Year  \
# 0   India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 1   India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 2   India  Andhra Pradesh  Calendar Year (Jan - Dec), 2024
# 3   India           Assam  Calendar Year (Jan - Dec), 2024
# 4   India           Assam  Calendar Year (Jan - Dec), 2024
#
#                 High Court Name                High Court Bench  \
# 0  High Court of Andhra Pradesh  Principal Bench Andhra Pradesh
# 1  High Court of Andhra Pradesh  Principal Bench Andhra Pradesh
# 2  High Court of Andhra Pradesh  Principal Bench Andhra Pradesh
# 3            Gauhati High Court                    Aizawl Bench
# 4            Gauhati High Court                    Aizawl Bench
#
#   Court Case Type As On Date  \
# 0           Civil  10-Jul-24
# 1        Criminal  10-Jul-24
# 2           Total  10-Jul-24
# 3           Civil  10-Jul-24
# 4        Criminal  10-Jul-24
#
# ...

# %%
df5.describe()
# Out:
#        Cases Pending For A Period Of 0 To 1 Year At High Court (UOM:Number), Scaling Factor:1  \
# count                                         138.000000
# mean                                        20775.637681
# std                                         24482.379779
# min                                             0.000000
# 25%                                          1159.500000
# 50%                                         11698.500000
# 75%                                         31323.250000
# max                                        114385.000000
#
#        Cases Pending For A Period Of 1 To 3 Years At High Court (UOM:Number), Scaling Factor:1  \
# count                                         138.000000
# mean                                        14523.623188
# std                                         17265.175807
# min                                             0.000000
# 25%                                           448.750000
# ...

# %%
import pandas as pd

# %%
df1
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df1['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df1['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df1['Sub-Category'].value_counts().sort_values()
# Out:
# Sub-Category
# Copiers          68
# Machines        115
# Supplies        190
# Fasteners       217
# Bookcases       228
# Envelopes       254
# Tables          319
# Labels          364
# Appliances      466
# Chairs          617
# Accessories     775
# Art             796
# Storage         846
# Phones          889
# Furnishings     957
# Paper          1370
# Binders        1523
# Name: count, dtype: int64

# %%
df1['Sub-Category'].value_counts().sort_values(ascending=False)
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df1.sort_values('Category')
# Out:
#            Ship Mode      Segment        Country           City  \
# 0       Second Class     Consumer  United States      Henderson
# 8133  Standard Class    Corporate  United States         Dallas
# 1903     First Class    Corporate  United States    Springfield
# 6151    Second Class  Home Office  United States  San Francisco
# 6153     First Class    Corporate  United States   Philadelphia
# ...              ...          ...            ...            ...
# 1844  Standard Class     Consumer  United States        Seattle
# 3921    Second Class     Consumer  United States        Chicago
# 6173  Standard Class  Home Office  United States    Springfield
# 8348  Standard Class    Corporate  United States       Lawrence
# 2522  Standard Class  Home Office  United States  Oklahoma City
#
#               State  Postal Code   Region    Category Sub-Category     Sales  \
# 0          Kentucky        42420    South   Furniture    Bookcases   261.960
# ...

# %%
df1.sort_values(['Category','Profit'])
# Out:
#            Ship Mode      Segment        Country           City  \
# 9639    Second Class     Consumer  United States        Concord
# 27    Standard Class     Consumer  United States   Philadelphia
# 5320     First Class  Home Office  United States      Knoxville
# 8993  Standard Class    Corporate  United States       Columbia
# 463   Standard Class  Home Office  United States        Phoenix
# ...              ...          ...            ...            ...
# 8488    Second Class     Consumer  United States      Arlington
# 2623     First Class  Home Office  United States  New York City
# 4190  Standard Class     Consumer  United States         Newark
# 8153     First Class     Consumer  United States        Seattle
# 6826  Standard Class    Corporate  United States      Lafayette
#
#                State  Postal Code   Region    Category Sub-Category  \
# 9639  North Carolina        28027    South   Furniture       Tables
# ...

# %%
df1.drop_duplicates(subset=['Sub-Category'])
# Out:
#           Ship Mode    Segment        Country             City  \
# 0      Second Class   Consumer  United States        Henderson
# 1      Second Class   Consumer  United States        Henderson
# 2      Second Class  Corporate  United States      Los Angeles
# 3    Standard Class   Consumer  United States  Fort Lauderdale
# 4    Standard Class   Consumer  United States  Fort Lauderdale
# 5    Standard Class   Consumer  United States      Los Angeles
# 6    Standard Class   Consumer  United States      Los Angeles
# 7    Standard Class   Consumer  United States      Los Angeles
# 8    Standard Class   Consumer  United States      Los Angeles
# 9    Standard Class   Consumer  United States      Los Angeles
# 12   Standard Class   Consumer  United States          Concord
# 26     Second Class   Consumer  United States      Los Angeles
# 30   Standard Class   Consumer  United States     Philadelphia
# 53   Standard Class  Corporate  United States    New York City
# ...

# %%
df1.drop_duplicates(subset=['Sub-Category']).shape
# Out:
# (17, 13)

# %%
df1.shape
# Out:
# (9994, 13)

# %%
categories=df1.groupby('Category')
categories

# %%
len(df1)
# Out:
# 9994

# %%
len(categories)
# Out:
# 3

# %%
categories.size()
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# dtype: int64

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\hp\Downloads\health_data.csv.csv")

# %%
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data.rename(columns={'Duration':"Timing"})
# Out:
#      Timing  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# ..      ...    ...       ...       ...
# 164      60    105       140     290.8
# 165      60    110       145     300.0
# 166      60    115       145     310.2
# 167      75    120       150     320.4
# 168      75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data.rename(index={0:'firsrtentry',1:'secondentry'})
# Out:
#              Duration  Pulse  Maxpulse  Calories
# firsrtentry        60    110       130     409.1
# secondentry        60    117       145     479.0
# 2                  60    103       135     340.0
# 3                  45    109       175     282.4
# 4                  45    117       148     406.0
# ...               ...    ...       ...       ...
# 164                60    105       140     290.8
# 165                60    110       145     300.0
# 166                60    115       145     310.2
# 167                75    120       150     320.4
# 168                75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df=pd.read_csv("C:\\Users\\hp\\Documents\\NITISH_SIR_JI\\Mall_Customers.csv")

# %%
pd.concat([data,df])
# Out:
#      Duration  Pulse  Maxpulse  Calories  CustomerID  Gender   Age  \
# 0        60.0  110.0     130.0     409.1         NaN     NaN   NaN
# 1        60.0  117.0     145.0     479.0         NaN     NaN   NaN
# 2        60.0  103.0     135.0     340.0         NaN     NaN   NaN
# 3        45.0  109.0     175.0     282.4         NaN     NaN   NaN
# 4        45.0  117.0     148.0     406.0         NaN     NaN   NaN
# ..        ...    ...       ...       ...         ...     ...   ...
# 245       NaN    NaN       NaN       NaN       246.0    Male  30.0
# 246       NaN    NaN       NaN       NaN       247.0  Female  56.0
# 247       NaN    NaN       NaN       NaN       248.0    Male  29.0
# 248       NaN    NaN       NaN       NaN       249.0  Female  19.0
# 249       NaN    NaN       NaN       NaN       250.0  Female  31.0
#
#      Annual Income (k$)  Spending Score (1-100)
# 0                   NaN                     NaN
# 1                   NaN                     NaN
# ...

# %%
df.join(data)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 245         246    Male   30                 297                      69
# 246         247  Female   56                 311                      14
# 247         248    Male   29                 313                      90
# 248         249  Female   19                 316                      32
# 249         250  Female   31                 325                      86
#
#      Duration  Pulse  Maxpulse  Calories
# 0        60.0  110.0     130.0     409.1
# ...
